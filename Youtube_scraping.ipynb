# %%
pip install google-api-python-client
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.9 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.9 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.9 kB ? eta -:--:--
#      ------------ ------------------------- 30.7/96.9 kB 163.8 kB/s eta 0:00:01
#      ------------ ------------------------- 30.7/96.9 kB 163.8 kB/s eta 0:00:01
#      ---------------- --------------------- 41.0/96.9 kB 140.3 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/96.9 kB 182.2 kB/s eta 0:00:01
#      ------------------------ ------------- 61.4/96.9 kB 182.2 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/96.9 kB 171.1 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/96.9 kB 171.1 kB/s eta 0:00:01
#      -------------------------------------- 96.9/96.9 kB 191.2 kB/s eta 0:00:00
# ...

# %%
import os
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Request comments for the specified video
response = youtube.commentThreads().list(
    part='snippet',
    videoId=video_id,
    textFormat='plainText'
).execute()

# Process the response and print the comments
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    print(comment)
    print('---')
# Out:
# ❤❤❤
# ---
# 0:13; Ryan makes his first Kentrance in the video
# ---
# No one has to have Barbie dolls, or be a fan of Barbie to enjoy this movie. This movie had a nice meaning to it, never watched something like it.
# ---
# I can’t stop laughing when you flew of the roof
# ---
# I❤
# ---
# You need to pay me minium 300 bucks for watching this and lost an evening with friends, dogs, beer. Or  a good book alone. Barbie ppffff even i was little girl i played to soccer, boxing, stunts with bikes. And the barbie of my sis finished with shaved head and a green crest. 😂🖕🤘
# ---
# Can we just take a moment to know that greta made a good choice about doing the movie and Margot Robbie was a good barbie and for how long she had to be on heels
# ---
# Uma história incrível, através dela se passam muitos ensinamentos para a vida real, sem contar que mostra o quanto a mulher é importante na sociedade.
# ---
# I didn’t know Warner Bros made PG-13 films or R films or even… NC-17 films
# ---
# ...

# %%
import os
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Request comments for the specified video
next_page_token = None
while True:
    response = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        textFormat='plainText',
        pageToken=next_page_token
    ).execute()

    # Process the response and print the comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        print(comment)
        print('---')

    # Check if there are more pages of comments
    next_page_token = response.get('nextPageToken')
    if not next_page_token:
        break  # Corrected indentation here
# Out:
# ❤❤❤
# ---
# 0:13; Ryan makes his first Kentrance in the video
# ---
# No one has to have Barbie dolls, or be a fan of Barbie to enjoy this movie. This movie had a nice meaning to it, never watched something like it.
# ---
# I can’t stop laughing when you flew of the roof
# ---
# I❤
# ---
# You need to pay me minium 300 bucks for watching this and lost an evening with friends, dogs, beer. Or  a good book alone. Barbie ppffff even i was little girl i played to soccer, boxing, stunts with bikes. And the barbie of my sis finished with shaved head and a green crest. 😂🖕🤘
# ---
# Can we just take a moment to know that greta made a good choice about doing the movie and Margot Robbie was a good barbie and for how long she had to be on heels
# ---
# Uma história incrível, através dela se passam muitos ensinamentos para a vida real, sem contar que mostra o quanto a mulher é importante na sociedade.
# ---
# I didn’t know Warner Bros made PG-13 films or R films or even… NC-17 films
# ---
# ...

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Comment'])

    # Request comments for the specified video
    next_page_token = None
    while True:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            csv_writer.writerow([comment])

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Comment', 'Like Count', 'User Name'])

    # Request comments for the specified video
    next_page_token = None
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            comment = comment_snippet['textDisplay']
            like_count = comment_snippet['likeCount']
            user_name = comment_snippet['authorDisplayName']

            csv_writer.writerow([comment, like_count, user_name])

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Like Count', 'Comment'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, like_count, comment])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Aboce success

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#now try to scrape user URL

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'pBk4NYhWNMM'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #1

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = '7J7aJtGphVs'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #2

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'RToUZJ0l7Pk'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #3

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'ie6eyTvf7Yw'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #4

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'iTcgwGYYp9Y'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #5

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'gKoGtv8ooao'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #6

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = '2CsTzVyZP4M'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #7

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 't3zIxWRIMWY'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #8

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'I-Mb5NqmHnE'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #9

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 't89aiVLgf1k'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #10

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = '-2vE-hFCpLc'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #11

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'ZION_-IsJro'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #12

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'Iobo_UJwwoE'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #13

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'GuWr-v3TOO8'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #14

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'zMvg2JzxHZQ'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #15

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'bJLSIP9TD3k'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #16

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'qubpJrfsyWs'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #17

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'i3SsbBG0_BE'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #18

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'hUkobjG5qUQ'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #19

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'SDFcF2bpFuk'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #20

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'oVba992SWPQ'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #21

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = '82z5-_V2Rss'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# %%
#Above #22

# %%
import os
import csv
import googleapiclient.discovery

# Set up the YouTube Data API client
api_key = 'AIzaSyCwFyp7RMK8sbd54TD82QQgQaYXHUu3UZY'
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Video ID of the YouTube video you want to retrieve comments from
video_id = 'KAuCfYKoxOY'

# Specify the CSV file path
csv_file_path = 'youtube_comments.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header
    csv_writer.writerow(['Order', 'User Name', 'Comment Date', 'Like Count', 'Comment', 'User Link'])

    # Request comments for the specified video
    next_page_token = None
    order = 1  # Initialize comment order
    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            textFormat='plainText',
            pageToken=next_page_token
        ).execute()

        # Process the response and write the comments to the CSV file
        for item in response['items']:
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            user_name = comment_snippet['authorDisplayName']
            like_count = comment_snippet['likeCount']
            comment = comment_snippet['textDisplay']
            comment_date = comment_snippet['publishedAt']  # Extract comment date and time
            user_link = comment_snippet['authorChannelUrl']  # Extract user link

            # Write the comment information to the CSV file
            csv_writer.writerow([order, user_name, comment_date, like_count, comment, user_link])

            order += 1  # Increment the comment order

        # Check if there are more pages of comments
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
